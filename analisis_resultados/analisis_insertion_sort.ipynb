# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
tamanios = [1,1000,2500,5000,7500,10000,12500,15000,17500,20000]
yCython = []
yPython = []

# %%
path = '/home/miguel/Desktop/computacion_paralela/final/insertion_sort/soluciones'
paths = []
files = os.listdir(path)
for file in files:
    paths.append(str(path + '/' + file))

# %%
paths.sort()
paths
# Out:
# ['/home/miguel/Desktop/computacion_paralela/final/insertion_sort/soluciones/0.main.py-size1.csv',
#  '/home/miguel/Desktop/computacion_paralela/final/insertion_sort/soluciones/1.main.py-size1000.csv',
#  '/home/miguel/Desktop/computacion_paralela/final/insertion_sort/soluciones/2.main.py-size2500.csv',
#  '/home/miguel/Desktop/computacion_paralela/final/insertion_sort/soluciones/3.main.py-size5000.csv',
#  '/home/miguel/Desktop/computacion_paralela/final/insertion_sort/soluciones/4.main.py-size7500.csv',
#  '/home/miguel/Desktop/computacion_paralela/final/insertion_sort/soluciones/5.main.py-size10000.csv',
#  '/home/miguel/Desktop/computacion_paralela/final/insertion_sort/soluciones/6.main.py-size12500.csv',
#  '/home/miguel/Desktop/computacion_paralela/final/insertion_sort/soluciones/7.main.py-size15000.csv',
#  '/home/miguel/Desktop/computacion_paralela/final/insertion_sort/soluciones/8.main.py-size17500.csv',
#  '/home/miguel/Desktop/computacion_paralela/final/insertion_sort/soluciones/9.main.py-size20000.csv']

# %%
for path in paths:
    df = pd.read_csv(path)
    yCython.append(df['Cython'].mean())
    yPython.append(df['Python'].mean())

# %%
plt.plot(tamanios, yPython, label='Python')
plt.plot(tamanios, yCython, label='Cython')
plt.xlabel('Tamaño del arreglo (N)')
plt.ylabel('tiempo (s)')
plt.title("Python vs. Cython: Algoritmo Insertion Sort")
plt.legend()

# %%
res = []
for i in range(len(yPython)):
    veces = yPython[i] / yCython[i]
    res.append(veces)
    print(f'Cython es {veces} veces mas rapido que Python')

resultado = sum(res)/len(yCython)
print(resultado)
# Out:
# Cython es 0.02464444617272092 veces mas rapido que Python
# Cython es 85.26762770387442 veces mas rapido que Python
# Cython es 113.12313294996656 veces mas rapido que Python
# Cython es 121.56681710077136 veces mas rapido que Python
# Cython es 127.73335607006227 veces mas rapido que Python
# Cython es 129.26830181294554 veces mas rapido que Python
# Cython es 126.0691488170615 veces mas rapido que Python
# Cython es 129.0953648832657 veces mas rapido que Python
# Cython es 132.37425379528608 veces mas rapido que Python
# Cython es 133.72560998581417 veces mas rapido que Python
# 109.82482575652205

# %%
fig, ax = plt.subplots()
x = np.arange(len(tamanios))
y1 = yCython
y2 = yPython
width = 0.2
plt.figure(figsize=(15,10))
# plot data in grouped manner of bar type
plt.bar(x, y1, width)
plt.bar(x-0.2, y2, width)
plt.xticks(x, tamanios)
plt.title("Cython vs. Python: Insertion Sort Performance")
plt.xlabel("Tamaño del Arreglo (N)")
plt.ylabel("Segundos (s)")
plt.legend(['Cython', 'Python'])

# %%
cython = []
python = []

for i in range(len(yCython)):
    cython.append(yCython[i]/tamanios[i])
    python.append(yPython[i]/tamanios[i])

# %%
c = sum(cython)/len(cython)

# %%
p = sum(python)/len(python)

# %%
print(p/c)
# Out:
# 53.803274252891285

# %%
opCy = []
opPy = []
for i in range(len(yCython)):
    opCy.append(yCython[i]/tamanios[i])
    opPy.append(yPython[i]/tamanios[i])

promedioCython = sum(opCy)/len(opCy)
promedioPython = sum(opPy)/len(opPy)

print(f'Promedio Cython: {promedioCython}')
print(f'Promedio Python: {promedioPython}')
# Out:
# Promedio Cython: 1.2573586287838612e-05
# Promedio Python: 0.0006765001113869741

# %%
yPython
# Out:
# [1.8040338666666677e-06,
#  0.06919581095393333,
#  0.43348857561753346,
#  1.7228794336319335,
#  3.8754122575123664,
#  6.907577013969367,
#  11.091734059651703,
#  16.9602599382401,
#  23.9912996610006,
#  31.591929729779565]

# %%
yCython
# Out:
# [7.320245113333336e-05,
#  0.0008115132649666666,
#  0.0038320064545,
#  0.014172283808366663,
#  0.030339860916099994,
#  0.05343596935283333,
#  0.08798135121660002,
#  0.1313777605693,
#  0.18123841285710002,
#  0.23624442418419994]

# %%
tamanios.insert(0,0)
yPython.insert(0,0)
yCython.insert(0,0)

# %%
eq_python = np.polyfit(tamanios, yPython, 2)
eq_python
# Out:
# array([ 8.76454083e-08, -1.81409397e-04,  1.01282598e-01])
